# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Mean

# %% [markdown]
# The mean is the average of the numbers. It is easy to calculate: add up all the numbers, then divide by how many numbers there are. In other words it is the sum divided by the count.

# %% [markdown]
# Example: Mean of 6,11,7

# %%
A =[6,11,7]

# %%
def mean(A):
    return sum(A)/len(A)

# %%
mean(A)
# Out:
# 8.0

# %% [markdown]
# ## Median

# %% [markdown]
# The Median is the "middle" of a sorted list of numbers. To find the Median, place the numbers in value order and find the middle.

# %% [markdown]
# Ezample: Median of 12,3,5

# %%
A = [12,3,27,11,7,1]
A = sorted(A)
A
# Out:
# [1, 3, 7, 11, 12, 27]

# %%
def median(A):
    if len(A)%2==1:
        return A[len(A)//2]
    else:
        return (A[(len(A)//2)-1] + A[len(A)//2])/2

# %%
median(A)
# Out:
# 9.0

# %% [markdown]
# ## Mode

# %% [markdown]
# The mode is simplt the number which appears most often. We can have more than one mode. Having two modes is called "bimodal". Having more than two modes is called "multimodal"

# %% [markdown]
# Example: Mode of 6, 3, 9, 6, 6, 5, 9, 3

# %%
A = [6,3,9,6,6,5,9,3,3]

# %%
def mode(A):
    count = {}
    mode = []
    for i in A:
        if i not in count:
            count[i]=1
        elif i in count:
            count[i ]+=1
    for key,value in zip(count.keys(),count.values()):
        if value == max(count.values()):
            mode.append(key)
    return mode

# %%
mode(A)
# Out:
# [6, 3]

# %% [markdown]
# ## Variance

# %% [markdown]
# The Variance is defined as: The average of the squared differences from the Mean. To calculate the variance follow these steps:
# 1. Work out the mean (The simple average of the numbers)
# 2. Then for each number: substract the mean and square the result (the squared difference).
# 3. Then work out the average of those squared differences.

# %%
A = [2,5,6,1,8]

# %%
def variance(A):
    squared_diff = []
    for i in A:
        squared_diff.append((i-mean(A))**2)
    return mean(squared_diff)

# %%
variance(A)
# Out:
# 6.640000000000001

# %% [markdown]
# ## Standard Deviation

# %% [markdown]
# The Standard Deviation is a measure of how spread out numbers are. The formula ia easy: it is the square root of the variance.

# %%
A = [2,5,6,1,8]

# %%
def standard_deviation(A):
    return variance(A)**(1/2)

# %%
standard_deviation(A)
# Out:
# 2.5768197453450252

# %% [markdown]
# ## Normal Distribution

# %% [markdown]
# 1. The Normal Distribution has mean = median = mode symmetry about the center 50% of values less than the mean and 50% of values greater than the mean.
#
# 2. Data can be "distributed" (spread out) in different ways. But there are many cases where the data tends to be around the central value with no bias left or right, and it gets close to a "Normal Distribution" like this.
#
# 3. It is often called a "Bell Curve" because it looks like a bell. Many things closely follow a Normal Distribution: heights of people, size of things produced by machines errors in measurements, blood pressure, marks on a test.

# %% [markdown]
# ![Screen%20Shot%202020-07-27%20at%202.40.10%20AM.png](attachment:Screen%20Shot%202020-07-27%20at%202.40.10%20AM.png)

# %% [markdown]
# ## Continuos Random Variable

# %% [markdown]
# Continuos Random Variable is a random variable where the data can take infinitely many values. For example, a random variable measuring the time taken for something to be done is continuous since there are an infinite number of possible times that can be taken.

# %% [markdown]
# ### Probability Density Function

# %% [markdown]
# Probability density function (pdf) is a statistical expression that defines a probability distribution for a continuos random variables opposed to a discrete random variable. When the PDF is graphically portrayed, the area under the curve will indicate the interval in which the variable will fall. The total area in this interval of the graph equals the probability of a continuos random variable occuring.

# %% [markdown]
# ## Skewed Data

# %% [markdown]
# ### Positve Skew

# %% [markdown]
# ![Screen%20Shot%202020-07-27%20at%202.37.46%20AM.png](attachment:Screen%20Shot%202020-07-27%20at%202.37.46%20AM.png)

# %% [markdown]
# 1. Positive skew is when the long tail is on the positive side of the peak, and some people say it is "Skewed to the right"
# 2. THe mean is on the right of the peak value.

# %% [markdown]
# ### Normal Distribution

# %% [markdown]
# ![Screen%20Shot%202020-07-27%20at%202.40.10%20AM.png](attachment:Screen%20Shot%202020-07-27%20at%202.40.10%20AM.png)

# %% [markdown]
# 1. A Normal Distribution is not skewed.
# 2. It is perfectly symmertrical.
# 3. Mean is exactly at the peak.

# %% [markdown]
# ### Negative Skew

# %% [markdown]
# ![Screen%20Shot%202020-07-27%20at%202.42.45%20AM.png](attachment:Screen%20Shot%202020-07-27%20at%202.42.45%20AM.png)

# %% [markdown]
# 1. Why is it called negative skew? Because the long "tail" is on the negative side of the peak.
# 2. People sometimes say it is "skewed to the left" (the long tail is on the left hand side)
# 3. The mean is also on the left of the peak.

# %% [markdown]
# ### Outlier

# %% [markdown]
# A value that "lies outside" (is much smaller or larger than) most of the other values in a set of data.

# %%
import matplotlib.pyplot as plt

# %%
A = [1,19,20,18,22]

# %%
plt.show(plt.boxplot(A))

# %% [markdown]
# ## Median Absolute Deviation

# %% [markdown]
# Median Absolute Deviation (MAD) is a robust measure of how spread out a set of data is.The variance and standard deviation are also measures of spreadm but they are more affected by extremely hidh or extremelt low values and non normality.

# %% [markdown]
# #### Steps:

# %% [markdown]
# 1. Calculate the Median.
# 2. Calculate how far away each data point is from the median using positive distances. These are called absolute deviations.
# 3. Find the median of the absolute differences.

# %% [markdown]
# ### Quartiles

# %% [markdown]
# Quartiles are the values that divide a list of numbers into quarters:
# 1. Put the list of numbers in order
# 2. Then cut the list into four equal parts
# 3. The Quartiles are at the "cuts"

# %% [markdown]
# Examples: 5,7,4,4,6,2,8
# Put them in order: 2,4,4,5,6,7,8
#
# And the result is:
#
#     Quartile1 (Q1) = 4
#     Quartile2 (Q2), which is also the Median, =5
#     Quartile3 (Q3) = 7

# %% [markdown]
# ### Percentiles

# %% [markdown]
# The value below which a percentage of data falls.

# %% [markdown]
# Example: You are the fourth tallest person in a group of 20.
#
#     80% of people are shorter than you
#
# That means you are the 80th percentile. If your height is 1.85m then "1.85m" is the 80th percentile height in that group.

# %% [markdown]
# ### Box and Whisker Plots

# %% [markdown]
# We can show all the important values in a "Box and Whisker Plot", like this:

# %% [markdown]
# ![Screen%20Shot%202020-07-28%20at%2011.59.48%20PM.png](attachment:Screen%20Shot%202020-07-28%20at%2011.59.48%20PM.png)

# %% [markdown]
# Example: Box and Whisker plot
#
#     4,17,7,14,18,12,3,16,10,4,4,11
#
# Put them in order:
#
#     3,4,4,4,7,10,11,12,14,16,17,18
#
# Cut it into Quarters:
#
#     3,4,4|4,7,10|11,12,14|16,17,18
#
# In this case all the quartiles are between numbers:
#
#     Quartile 1 (Q1) = (4+4)/2 =4
#     Quartile 2 (Q2) = (10+11)/2 = 10.5
#     Quartile 3 (Q3) = (14+16)/2 = 15
#
# Also the lowest value is 3,
# The highest value is 18

# %% [markdown]
# ## Kurtosis

# %% [markdown]
# 1. A positive value tells you that you have heavy-tails (i.e., a lot of data in youe tails)
# 2. A negative value tells you that you have light-tails (i.e., little data in you tails)
# 3. This heaviness or lightness in the tails usually means that your data looks flatter (or less flat) compared to the normal distribution. The standard normal distribution has a kurtosis of 3, so if your values are close to that then youe graph's tails are nearly normal.

# %% [markdown]
# ![Screen%20Shot%202020-07-29%20at%202.59.11%20PM.png](attachment:Screen%20Shot%202020-07-29%20at%202.59.11%20PM.png)

# %% [markdown]
# ### Univariate Analysis

# %% [markdown]
# Univariate Analysis is the simplest form of data analysis where the data being analyzed contains only one variable. Since it;s a single variable it doesn't deal with causes or relationships. The main purpose of univariate analysis is to describe the data and find patterns that exist within it
#
# You can think of the variables as a category that your data falls into.

# %% [markdown]
# ### Bivariate Analysis

# %% [markdown]
# Bivariate analysis is used to find out if there is a relationship between two different variables. Something as simple as creating a scatter plot by plotting one variable against another on a Cartesian plane (think X and Y axis) can sometimes giveyou a picture of what the data is trying to tell you. If the data seems to fit a line or curve then there is a relationship or correlation between the two variables.

# %% [markdown]
# ### Multivariate Analysis

# %% [markdown]
# Multivariate Analysis is the analysis of three or more variables. There are many ways to perform multivariate analysis depending on your goals. Some of these methods include Additive Tree, Canonical Correlation Analysis, Cluster Analysis, Correspindence Analysis / Multiple Correspondence Analysis, Factor Analysis, Generalized Procrustean Analysis, MANOVA, Multidimensional Scaling, Multiple Regression Analysis, Partial Least Square Regression, Principal Component Analysis / Regression / PARAFAC, and Redundancy Analysis.

# %% [markdown]
# ## Why Scaling?

# %% [markdown]
# Most of the times, your dataset will contain features highly varying in magnitudes, units and range. But since, most of the machine learning algorithms use Eucledian distance between two points in their computations, this is a problem.
#
# If left alone, these algorithms only take in the magnitude of features neglecting the units. The results would vary greatly between different units, 5kgs and 5000gms. The features with high magnitudes will weigh in a lot more in the distance calculations than features with low magnitudes.

# %% [markdown]
# ## When Scaling?

# %% [markdown]
# Any algorithm that computes distance or assumes normality, scale your features. Some examples of features where feature scaling matters are:
#
#     1. KNN
#     2. PCA
#     3. Gradient Descent
#     4. Tree Models
#     5. LDA (Latent Dirichlet Allocation)

# %% [markdown]
# ## How Scaling?

# %% [markdown]
# There are four common methods to perfrom Feature Scaling.
#
#     1. Standardisation
#     2. Mean Normalization
#     3. Min-Max Scaling
#     4. Unit Vector

# %% [markdown]
# ### Standardization

# %% [markdown]
# Data Standardization is the process of rescaling one or more attributes so that they have a mean value of 0 and a standard deviation of 1.
#
# Standardization assumes that your data has a Guassian (bell curve) distribution. This does not strictly have to be true, but the technique is more effective if your attribute distribution is Gaussian.
#
# Standardization replaces the values by their Z scores.

# %% [markdown]
# ![Screen%20Shot%202020-08-01%20at%2012.15.37%20AM.png](attachment:Screen%20Shot%202020-08-01%20at%2012.15.37%20AM.png)

# %% [markdown]
# This redistributes the features with their mean = 0 and standard deviation =1. sklearn.preprocessing.scale helps us implementing standardisation in python.

# %% [markdown]
# ### Normalization

# %% [markdown]
# Data Normalization is the process of rescaling one or more attributes to the range of 0 to 1. This means that the largest value for each attribute is 1 and the smallest value is 0.
#
# Normalization is a good technique to use when you do not know the distribution of your data or when you know the distribution is not Gaussian (a bell curve).
#
# This distribution will have values between -1 and 1 with mean = 0. Standardisation and Mean Normalization can be used for algorithms that assumes zero centric data like Principal Component Analysis(PCA).

# %% [markdown]
# ![Screen%20Shot%202020-08-01%20at%2012.49.06%20AM.png](attachment:Screen%20Shot%202020-08-01%20at%2012.49.06%20AM.png)

# %% [markdown]
# ### Min-Max Scaling

# %% [markdown]
# This scaling brings the value between 0 and 1.

# %% [markdown]
# ![Screen%20Shot%202020-08-01%20at%2012.51.09%20AM.png](attachment:Screen%20Shot%202020-08-01%20at%2012.51.09%20AM.png)

# %% [markdown]
# ## Kernel Density Estimation

# %% [markdown]
# Kernel density estimation (KDE) is a non-parametric way to estimate the probability density function of a random variable. Kernel density estimation is a fundamental data smoothing problem where inferences about the population are made, based on a finite data sample.

# %% [markdown]
# ![Screen%20Shot%202020-08-01%20at%201.04.57%20AM.png](attachment:Screen%20Shot%202020-08-01%20at%201.04.57%20AM.png)

# %% [markdown]
# This can be useful if you want to visualize just the "shape" of some data, as a kind of continuous replacement for the discrete histogram. It can also be used to generate points that look like they came from a certain dataset - this behavior can power simple simulations, where simulated objects are modeled off of real data.

# %% [markdown]
# The KDE algorithm takes a parameter, bandwidth, that affects how "smooth" the resulting curve is. Use the control below to modify bandwidth, and notice how the estimate changes. The KDE is calculated by weighting the distances of all the data points Changing the bandwidth changes the shape of the kernel: a lower bandwidth means only points very close to the current position are given any weight, which leads to the estimate looking squiggly; a higher bandwidth means a shallow kernel where distant points can contribute.

# %% [markdown]
# ## Central Limit Theorem

# %% [markdown]
# The central limit theorem states that when samples from a data set with a known variance are aggregated their mean roughly equals the population mean. Said another way, CLT is a statistical theory that states that given a sufficiently large sample size from a population with a finite level of variance, the mean of all samples from the same population will be approximately equal to the mean of the population. Furthermore, all the samples will follow an approximate normal distribution pattern, with all variances being approximately equal to the variance of the population divided by each samples's size.

# %% [markdown]
# Suppose we draw a random sample of size n(x1,x2,x3,......xn) from a population random variable that is distributed with mean and standard deviation. Do this repeatedly, drawing many samples from the population, and then calculate the x̄ of each sample. We will treat the x̄ values as another distribution, which we will call the sampling distribution of the mean (x̄). Central Limit Theorem is that no matter what the shape of the original (parent) distribution, the sampling distribution of the mean approaches a normal distribution. A normal distribution is approached very quickly as n increases, Note that n is the sample size for each mean and not the number of samples. Remember in a sampling distribution of the mean the number of samples is assumed to be infinte.

# %% [markdown]
# Example:
#
#     On the right are shown the resulting frequency distributions each based on 500 means. For n=4,4 scores were sampled from a uniform distribution 500 times and the mean computed each time. The same methods was followed with means of 7 scores for n=7 and 10 scores for n=10.

# %% [markdown]
# ![Screen%20Shot%202020-08-03%20at%2011.52.56%20PM.png](attachment:Screen%20Shot%202020-08-03%20at%2011.52.56%20PM.png)

# %% [markdown]
# When n increases
#
# 1. The distribution becomes more and more normal
# 2. The spread of the distributions decreases.
#
#     Thumb rule is n=30

# %% [markdown]
# ## Q-Q Plot

# %% [markdown]
# The quantile-quantile (q-q) plot is a graphical technique for determining if two data sets come from populations with a common distribution. A q-q plot is a plot of the quantiles of the first data set against the quantiles of the second data set. By a quantile, we mean the fraction (or precent) of poinths below the given value.

# %% [markdown]
# ![Screen%20Shot%202020-08-05%20at%202.16.49%20AM.png](attachment:Screen%20Shot%202020-08-05%20at%202.16.49%20AM.png)

# %% [markdown]
# A Q-Q plot is a scatterplot created by plotting two sets of quantiles against one another. If boths sets of quantiles came from the same distribution, we should see the points forming a line that's roughly straight.

# %% [markdown]
# ### Advantages of Q-Q plot:

# %% [markdown]
# 1. The sample sizes do not need to be equal.
# 2. Many distributional aspects can be simultaneously tested.
# For example: shifts in location, shifts in scale, changes in symmetry, and the presence of outliers can all be detected from this plot. For example, if the two data sets come from populations whose distributions differ only by a shift in location, the points should lie along a straight line that is displaced either up or down from the 45-degree reference line

# %% [markdown]
# The Q-Q plot is similat to probability plot. For a probalbility plot, the quantiles for one of the data samples are replaced with the quantiles of a theoritical distribution.

# %% [markdown]
# #### The q-q plot is used to answer the following questions:

# %% [markdown]
# 1. Do two data sets come from population with a common distribution?
# 2. Do two data sets have common location and scale?
# 3. Do two data sets have similar distributional shapes?
# 4. Do two data sets have similar tail behavior?

# %% [markdown]
# #### How to draw Q-Q plot

# %% [markdown]
# 1. Sort the values which we got from the population.
# 2. Get the quantiles from that sorted values.
# 3. Do the same with the other population values also
# 4. Plot the both quantile values and check whether they are forming the 45 degree straight line. If not they are not from the same distribution.

# %% [markdown]
# ## Bernoulli Distribution

# %% [markdown]
# The Bernoulli distribution essentially models a single trial of flipping a weighted coin. It is the probability distribution of a random variable taking on only two values, ("Success") "1" and "0" ("failure") with complementary probabilities "P" and "1-P" respectively. The Bernoulli distribution therefore describes events having exactly two outcomes, which are ubiquitous in real life. Some examples of such events are as follows: a team will win a championship or not, a student will pass or fail an exam, and a rolled dice will either show 6 or any other number.

# %% [markdown]
# p(X = x) = p for x = 1
#
#
# p(X = x) = 1-p for x=0

# %% [markdown]
# ## Binomial Distribution

# %% [markdown]
# The binomial distribution is, in essence, the probability distribution of the number of heads resulting from flipping a weighted coin multiple times. It is useful for analyzing the results of repeated independent trails, especially the probability of meeting a particular threshold given a specific error rate, and thus has applications to risk management. For this reason, the binomial distribution is also important in determining statistical significance.

# %% [markdown]
# #### A Bernouli trial, or Bernoulli experiment, is an experiment satisfying two key properties:

# %% [markdown]
# 1. These are exactly two complementary outcomes, success and failure.
# 2. The probability of success is the same every time the experiment is repeated.

# %% [markdown]
# A binomial experiment is a series of "n" Bernoulli trials, whose outcomes are independent of each other. A random variable, "X", is defined as the number of successes in a binomial experiment. Finally, a binomial distribution is the probability distribution of "X".

# %% [markdown]
# For example, consider a fair coin. Flipping the coin once is a Bernoulli trail, since there is exactly two complementary outcomes (flipping a head or a tail), and they are both 1/2 no matter how many times the coin is flipped. Note that the coin is fair is not necessary; flipping a weighted coin is still a Bernoulli trial.

# %% [markdown]
# A binomial experiment might consist of flipping the coin 100 times, with the resulting number of heads being represented by the random variable "X". The binomial distribution of this experiment is the probability distribution of "X".

# %% [markdown]
# ## Power Law Distribution

# %% [markdown]
# The power law (also called the scalling law) states that a relative change in one quantity results in a proportional relative change in another. The simplest example of the law in action is a sqare; if you double the length of a side (say, from 2 to 4 inches) then the area will quadruple (from 4 to 16 inches squared).

# %% [markdown]
# The powe law can be used to describe a phenomenon where a small number of items is clustered at the top of a distribution (or at the bottom), taking up 95% of the resources. In other words, it implies a small amount of occurances is common, while larger occurences are rare. For example, where the distribution of income is concerned, there are very few billionaires; the bulk of the population holds very modest nest eggs.

# %% [markdown]
# ![Screen%20Shot%202020-08-06%20at%2011.28.57%20PM.png](attachment:Screen%20Shot%202020-08-06%20at%2011.28.57%20PM.png)

# %% [markdown]
# ## Covariance

# %% [markdown]
# Covariance is a measure of the relationship between two random variables. The metric evaluates how much - to what extent - the variables change together. In other words, it is essentially a measure of the variance between the two variables. Unlike the correlation coefficient, covariance is measured in units. The units are computed by multiplying the units of the two variables. The variance can take any positive or negative values.

# %% [markdown]
# Positive Covariance: Indicates that two variables tend to move in the same direction
# Negative Covariance: Reveals that two variables tend to move in inverse direction.

# %% [markdown]
# Covariance formula is similar to the formula for correlation and deals with the calculation of data points from the average value in a dataset. For example, the covariance between two random variables X and Y can be calculated using the following formula.

# %% [markdown]
#     Cov(X,Y) =
#
#             sum((Xi - X̄)(Yj - Ŷ))
#            ________________________
#
#                       n

# %% [markdown]
#     Xi - the values of the X-variable
#     Yj - the values of the Y-variable
#     X̄  - the mean (average) of the X-variable
#     Ŷ  - the mean (average) of the Y-variable
#     n  - the number of the data points

# %% [markdown]
# ## Correlation

# %% [markdown]
# Correlation is a bivariate analysis that measures the strength of association between two variables and the direction of the relationship. In terms of the strength of relationship, the value of the correlation coefficient varies between +1 and -1. A value of +1 or -1 indicates a perfect degree of association between the two variables. As the correlation coefficient value goes towards 0, the relationsip between the two variables will be weaker. The direction of the relationship is indicated by the sign of the coefficient; a +sign indicates a positive relationsip and a -sign indicates a negative relationsip.

# %%
correlation = plt.imread('Statistics Images/Screen Shot 2020-08-07 at 8.23.43 PM.png')
plt.figure(figsize=(90,10))
plt.imshow(correlation)

# %%
correlation_examples = plt.imread('Statistics Images/Screen Shot 2020-08-07 at 8.35.31 PM.png')
plt.figure(figsize=(90,10))
plt.imshow(correlation_examples)

# %% [markdown]
# ## Covariance vs Correlation

# %% [markdown]
# Covariance and Correlation both mainly assess the relationship between the variables.

# %% [markdown]
# Covariance measures the total variation of two random variables from their expected values. Using covariance, we only gauge the direction of the relationship (whether the variables tend to move in tandem or show and inverse relationship). However, it does not indicate the strenfth of the relationship, nor the dependency between the variables.

# %% [markdown]
# Correlation measures the strength of the relationship between variables. Correlation is the scaled measure of covariance. It is dimensionless. In other words, the correlation coefficient is always a pure value and not measured in any units.

# %% [markdown]
# The relationship between the two concepts can be expressed using the formula below:

# %%
cov_vs_corr = plt.imread('Statistics Images/Screen Shot 2020-08-07 at 8.43.45 PM.png')
plt.figure(figsize=(10,10))
plt.imshow(cov_vs_corr)

# %% [markdown]
# ## Spearman Correlation Coefficient

# %% [markdown]
# Spearman's rank correlation coefficient or Spearman's rho, named after Charles Spearman and often denoted by the Greek letter (rho). It is the nonparametric version of the Pearson correlation coefficient. your data mustbe ordinal, interval or ratio. Spearman's returns a value from -1 to 1, where:
#
#     +1 = a perfect positive correlation between ranks
#     -1 = a perfect negative correlation between ranks
#      0 = no correlation between ranks.

# %% [markdown]
# 1. It assesses how well the relationship between two variables can be described using a monotonic function.
# 2. While pearson's correlation assesses linear relationships, Spearmans's correlation assesses monotonic relationships.

# %% [markdown]
# A Spearman correlation of 1 results when the two variables being compared are monotonically related, even if their relationship is not linear. This means that all data-points which greater x-values than that of a given data-point will have greater y-values as well. in contrast, this does not give a perfect Peasrson correlation.

# %%
spearson_correlation_of_1_result = plt.imread('Statistics Images/Screen Shot 2020-08-07 at 8.55.58 PM.png')
plt.figure(figsize=(7,7))
plt.imshow(spearson_correlation_of_1_result)

# %% [markdown]
# When the data are roughly elliptically distributed and there are no prominent outliers, the Spearman correlation and Pearson correlation give similar values.

# %%
spearson_correlation_elliptical_distribution = plt.imread('Statistics Images/Screen Shot 2020-08-07 at 8.56.08 PM.png')
plt.figure(figsize=(7,7))
plt.imshow(spearson_correlation_elliptical_distribution)

# %% [markdown]
# ## Correlation Vs Causation

# %% [markdown]
# People use these two words interchangeably, Which brings confusion to the people which word we need to use in what time. Lets remove the confusion and understand it properly when to use both.
#
#    1. Correlation refers to the degree of association between two random variables.
#    2. Causation is implying that A and B have a cause-and-effect relationship with one another. You're saying A   causes B.

# %% [markdown]
# Causation takes a step further than correlation. It says any change in the value of one variable will cause a change in the value of another variable, which means one variable makes other to happen. It is also referred as cause and effect. An example would be hot weather causes increase in number of sunburn cases.

# %%
corr_vs_causation = plt.imread('Statistics Images/Screen Shot 2020-08-07 at 9.20.49 PM.png')
plt.figure(figsize=(7,7))
plt.imshow(corr_vs_causation)

# %% [markdown]
# Lets consider another example where we use these two words.

# %% [markdown]
# Suppose when you are using your mobile phone like you open many applications which are running in the background and you are trying to text someone but your mobile is freeze and you are unable to text. what you think of this because of freeze you are unable to text. But immediately you are able to text back. But is that the reason, "NO" because of lack of RAM your mobile is freeze and you are unable to text.

# %% [markdown]
# Here correlation is freeze and unable to text, cause is Lack of RAM

# %% [markdown]
# Majority of the cases correlation, are just because of the coincidences. Just because it seems like one factor is influencing the other, it does not mean that it actually does. Here in out example freezing doesn't allowing you to text. But it seems like it is doing that.

# %% [markdown]
# Dont conclude too fast!

# %% [markdown]
# There is a quote. "Correlation does not imply causation"

# %% [markdown]
# ## Bootstrapping

# %% [markdown]
#     It is a method which is used to estimate statistical methods on a population by resampling the data.
#
#     It uses a sampling with replacement technique to make sure that drawn sample data every time should be present in  population data to see that data again in other samples.
#
#     The two important things in bootstrapping are the size of a sample and how many samples.
#
#     The steps invovled are:
#         1. Draw a sample from the population
#         2. Perform statistics on that sample.
#         3. Do that on multiple replacements samples.
#         4. Calculate the mean of all those computed samples.
#
#     The two parameters need to take care of our sample size and no of repetitions.
#
#     Sample Size:
#         We can take whole daat as sample data. Where few data is repeated and few are not present. If the dataset is huge and computational expensive then you can use 40% or 50%.
#
#
#     Repetitions:
#         This can be your choice when you are trying to get meaning dull results like mean, standard deviation or variance. The thumb is to use between 20-30. If you have more resources and time then you can do more.
#
#     Bootstrapping does not make assumptions about the distribution of your data. You merely resample your data and use whatever sampling distribution emerges. Then, you work with that distribution, whatever it might be.

# %% [markdown]
# ## Conditional Probability

# %% [markdown]
# The conditional probability of event A is given by the probability of A given probability of B is already completed.

# %% [markdown]
# This is the prerequisite topic in probability where we use this in machine learning.

# %% [markdown]
# P(A | B) = P(A and B) / P(B)

# %% [markdown]
#     P(A|B) is probability of event A given B has occured.
#     P(A and B) is probability of event A occurred and event B occurred.
#     P(B) is probability of B
